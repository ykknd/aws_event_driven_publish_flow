# %% [markdown]
# # Inventory Report
#
# Dummy notebook for scaffold validation.

# %%
from misc.notebook_utils import artifact_dir_from_env, job_context_from_env, write_dummy_csv, write_dummy_html, write_dummy_png

artifact_dir = artifact_dir_from_env()
job = job_context_from_env()
title = job.get('parameters', {}).get('title', 'Inventory Report')

write_dummy_csv(artifact_dir / 'inventory_summary.csv', [
    {'sku': 'A-100', 'stock': 120},
    {'sku': 'B-200', 'stock': 75},
])
write_dummy_html(artifact_dir / 'inventory_summary.html', title)
write_dummy_png(artifact_dir / 'inventory_chart.png')
print(f'Generated artifacts under {artifact_dir}')
